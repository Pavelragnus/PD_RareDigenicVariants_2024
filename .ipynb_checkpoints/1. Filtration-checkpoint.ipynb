# %%
import pandas as pd
import numpy as np
import os
import warnings
warnings.filterwarnings('ignore')
import dataframe_image as dfi

# %% [raw]
# def filtration(chromosome):
#     path = os.listdir(f'{chromosome}/')
#     result_df = pd.DataFrame()
#     for i in path:
#         df = pd.read_csv(f'{chromosome}/{i}', sep = '\t')
#         new_df = df.query(f"CHROM == {chromosome}").query("@df.ClinVar_CLNSIG.str.contains('pathogenic') == True or @df.ClinVar_CLNSIG.str.contains('Pathogenic') == True")
#         # new_df.to_csv(f'{chromosome}_res/{i}', index=False)
#         if  not new_df.empty:
#             new_df.index = [i]*len(new_df)
#             result_df = pd.concat([result_df, new_df[['CHROM', 'POS', 'ID', 'SYMBOL', 'Gene', 'HGVSc', 'gnomADg_AF_NFE', 'HGVSp', 'CADD_PHRED', 'ClinVar_CLNSIG', 'ClinVar_CLNDN', 'LoFtool', 'CAROL']]], ignore_index = False)
#
#     result_df.to_csv(f'{chromosome}_filtration_onlyClinVar.csv')

# %%
covar  = pd.read_table('covar_AMP_PD_old.txt', sep = '\t')
covar['Patient'] = covar['FID'] + '_' + covar['IID'] +'.csv'
covar = covar.astype({'Patient':str})
covar = covar.set_index('Patient')

# %%
covar

# %%
path = os.getcwd() 
l = os.listdir(path)
ls = [i for i in l if i.endswith('csv')]
df = pd.DataFrame()
for i in ls:
    d = pd.read_csv(i)
    print(f'{i} : {len(d)}')
    df = pd.concat([df, d])
df = df.rename(columns = {'Unnamed: 0': 'Patient'})
#df = df[(df['ClinVar_CLNSIG'] == 'Conflicting_interpretations_of_pathogenicity') == False]
#df = df[(df['ClinVar_CLNSIG'] == 'Conflicting_interpretations_of_pathogenicity&risk_factor') == False]
#df = df[(df['ClinVar_CLNSIG'] == 'Conflicting_interpretations_of_pathogenicity&other') == False]
#df = df[(df['ClinVar_CLNSIG'] == 'Conflicting_interpretations_of_pathogenicity&association') == False]
#df = df[(df['ClinVar_CLNSIG'] == 'Conflicting_interpretations_of_pathogenicity&drug_response') == False]
#df = df[(df['ClinVar_CLNSIG'] == 'Conflicting_interpretations_of_pathogenicity&association&risk_factor') == False]
df = df[df['gnomADg_AF_NFE'] < 0.01]
df = df[df['CADD_PHRED'] > 20]
df = df[df['CAROL'].notna()]
df = df.query('CAROL.str.contains("Deleterious")')
df = df.set_index('Patient')
dfs2 = df.astype({'HGVSc':str})
#df2 = dfs2[dfs2['HGVSc'].str.contains('NM_198578.4:c.6055G>A')]
#df2 = dfs2[(dfs2['HGVSc'].str.contains('NM_000157.4:c.1226A>G') == False) & (dfs2['HGVSc'].str.contains('NM_198578.4:c.6055G>A') == False)]
df2 = dfs2
df = df.loc[df2.index]
print(len(df))
aggfuncs = ['unique']
dfs = df.groupby('Patient')[['SYMBOL','ID', 'HGVSc', 'gnomADg_AF_NFE', 'ClinVar_CLNDN']].agg(lambda x: list(x))
#dfs = dfs.astype({'CADD_PHRED':float})
# Out:
# 10_filtration_onlyClinVar.csv : 11785
# 11_filtration_onlyClinVar.csv : 18886
# 12_filtration_onlyClinVar.csv : 11267
# 13_filtration_onlyClinVar.csv : 5764
# 14_filtration_onlyClinVar.csv : 10500
# 15_filtration_onlyClinVar.csv : 10506
# 16_filtration_onlyClinVar.csv : 15853
# 17_filtration_onlyClinVar.csv : 15502
# 18_filtration_onlyClinVar.csv : 4577
# 19_filtration_onlyClinVar.csv : 12083
# 1_filtration_onlyClinVar.csv : 25988
# 21_filtration_onlyClinVar.csv : 3669
# 22_filtration_onlyClinVar.csv : 4830
# 2_filtration_onlyClinVar.csv : 35708
# 3_filtration_onlyClinVar.csv : 12305
# 4_filtration_onlyClinVar.csv : 11289
# 5_filtration_onlyClinVar.csv : 14478
# 6_filtration_onlyClinVar.csv : 14417
# 7_filtration_onlyClinVar.csv : 12047
# 8_filtration_onlyClinVar.csv : 10825
# 9_filtration_onlyClinVar.csv : 12727
# 759089

# %% [raw]
# common['Patient'] = common.index
# l = common.Patient.values.tolist()
# common['Patient'] = [i[0] for i in [re.findall(r"\d+",str(i)) for i in common.Patient]]
# clean = pd.read_csv('Pheno/Participant_Status.csv')
# clean = clean.astype({'PATNO':str})
# clean = clean[(clean['COHORT_DEFINITION'] == 'Prodromal') == False]
# clear = set (common['Patient']) & set (clean['PATNO'])
# clear = list(clear)
# ubrat = common[common['Patient'].isin(clear)].index.tolist()
# len(ubrat)
# with open("ubrat_genetic.txt", 'w') as file:
#     for item in ubrat:
#         print(item, file=file)

# %% [raw]
# F = open('ubrat_prodrom.txt')
# ubrat = []
# for i in F:
#     ubrat.append(i.rstrip())
# dfs = dfs[~dfs['Patient'].isin(ubrat)]

# %%
common = dfs.join(covar)
common = common.dropna()
common = common[common['SYMBOL'].notna()]

# %%
common = common[common['SYMBOL'].notna()]
common2 = common.astype({'HGVSc':str})
#common2 = common2[(common2['HGVSc'].str.contains('NM_000157.4:c.1226A>G') == False) & (common2['HGVSc'].str.contains('NM_198578.4:c.6055G>A') == False)]
common = common.loc[common2.index]

# %% [raw]
# common = common[common['SYMBOL'].notna()]
# common2 = common.astype({'HGVSc':str})
# common2 = common2[common2['HGVSc'].str.contains('NM_000157.4:c.1226A>G')]
# common = common.loc[common2.index]

# %%
common
# Out:
#                                                                   SYMBOL  \
# Patient
# BF-1001_BF-1001.csv    [CEP164, PKD1, PLOD1, DEPDC5, FN1, PDE11A, OBS...
# BF-1002_BF-1002.csv    [MYO3A, MYBPC3, SERPINA1, TBCE, TTC21B, VCAN, ...
# BF-1003_BF-1003.csv    [TTLL5, PKD1, STAT5B, CPS1, SLC3A1, SPINK5, CP...
# BF-1004_BF-1004.csv    [GJB6, MIPEP, ATP7B, HEXA, FBN3, SBF1, NBAS, S...
# BF-1005_BF-1005.csv    [DGKZ, NUP93, HYDIN, MYO18B, NLRC4, PLS1, FBN2...
# ...                                                                  ...
# PP-75564_PP-75564.csv  [ACADSB, EFEMP2, HIKESHI, LRRK2, LIPC, PKD1, C...
# PP-85242_PP-85242.csv  [MYO3A, ZEB1, BLM, CEP152, TSC2, CREBBP, PIEZO...
# PP-90456_PP-90456.csv  [HPS1, MYBPC3, SUOX, KCNH5, NOD2, ACE, KIF1C, ...
# PP-92490_PP-92490.csv  [CTNNA3, MYO7A, VWA8, ETFA, DUOX2, MAPT, SPTA1...
# PP-92834_PP-92834.csv  [OTOGL, NOD2, IFIH1, PALLD, PEX6, ALDH5A1, FAN...
#
#                                                                       ID  \
# Patient
# BF-1001_BF-1001.csv    [rs143659874, rs144979397, rs149425237, rs1855...
# BF-1002_BF-1002.csv    [rs72787346, rs375776406, rs28929470, rs140662...
# BF-1003_BF-1003.csv    [rs142169707, rs148812376, rs148793995, rs1148...
# BF-1004_BF-1004.csv    [rs200172266, rs150167906, rs201738967, rs1219...
# BF-1005_BF-1005.csv    [rs76583617, rs145146218, rs79607350, rs149103...
# ...                                                                  ...
# PP-75564_PP-75564.csv  [rs148640214, rs141868759, rs202003795, rs3463...
# PP-85242_PP-85242.csv  [rs146511800, rs118020901, rs144706057, rs2013...
# PP-90456_PP-90456.csv  [rs200004304, rs202139499, rs139444405, rs1437...
# PP-92490_PP-92490.csv  [rs187752783, rs111033287, rs138075452, rs1412...
# PP-92834_PP-92834.csv  [rs76420383, rs61747625, rs139714761, rs140454...
#
#                                                                    HGVSc  \
# Patient
# BF-1001_BF-1001.csv    [NM_014956.5:c.380C>A, NM_001009944.3:c.8293C>...
# BF-1002_BF-1002.csv    [NM_017433.5:c.1559C>T, NM_000256.3:c.2980C>T,...
# BF-1003_BF-1003.csv    [NM_015072.5:c.2891G>A, NM_001009944.3:c.9829C...
# BF-1004_BF-1004.csv    [NM_001110219.3:c.212T>C, NM_005932.4:c.590T>C...
# BF-1005_BF-1005.csv    [NM_001199267.2:c.2660C>G, NM_014669.5:c.1162C...
# ...                                                                  ...
# PP-75564_PP-75564.csv  [NM_001609.4:c.1187A>C, NM_016938.5:c.977G>A, ...
# PP-85242_PP-85242.csv  [NM_017433.5:c.170A>C, NM_001174096.2:c.2522A>...
# PP-90456_PP-90456.csv  [NM_000195.5:c.179C>T, NM_000256.3:c.624G>C, N...
# PP-92490_PP-92490.csv  [NM_013266.4:c.1132C>T, NM_000260.4:c.5227C>T,...
# PP-92834_PP-92834.csv  [NM_001378609.3:c.1990C>T, NM_001370466.1:c.21...
#
#                                                           gnomADg_AF_NFE  \
# Patient
# BF-1001_BF-1001.csv    [0.00516024, 0.00743071, 0.00086632, 0.0003998...
# BF-1002_BF-1002.csv    [0.00273224, 0.00026688, 0.00346852, 0.0010658...
# BF-1003_BF-1003.csv    [0.00333023, 0.000867129, 6.66667e-05, 0.00773...
# BF-1004_BF-1004.csv    [0.0006, 0.00113303, 0.000400053, 0.00306585, ...
# BF-1005_BF-1005.csv    [0.00633925, 0.00239872, 0.00319787, 0.0068620...
# ...                                                                  ...
# PP-75564_PP-75564.csv  [0.000133245, 6.68449e-05, 6.66578e-05, 0.0003...
# PP-85242_PP-85242.csv  [0.00093633, 0.00879297, 0.00166578, 0.0050781...
# PP-90456_PP-90456.csv  [0.0, 6.66578e-05, 0.00020024, 6.66045e-05, 0....
# PP-92490_PP-92490.csv  [0.00140262, 0.00400588, 0.00767485, 0.0012659...
# PP-92834_PP-92834.csv  [0.00193411, 0.00539856, 0.000200428, 0.004334...
#
#                                                            ClinVar_CLNDN  \
# Patient
# BF-1001_BF-1001.csv    [not_provided&Nephronophthisis_15, Inborn_gene...
# BF-1002_BF-1002.csv    [not_provided&not_specified&Autosomal_recessiv...
# BF-1003_BF-1003.csv    [not_specified&not_provided, Autosomal_dominan...
# BF-1004_BF-1004.csv    [not_provided&Autosomal_recessive_nonsyndromic...
# BF-1005_BF-1005.csv    [atypical_cerebral_palsy&not_provided, Nephrot...
# ...                                                                  ...
# PP-75564_PP-75564.csv  [Deficiency_of_2-methylbutyryl-CoA_dehydrogena...
# PP-85242_PP-85242.csv  [Inborn_genetic_diseases&not_specified&not_pro...
# PP-90456_PP-90456.csv  [Hermansky-Pudlak_syndrome_1&not_provided&Herm...
# PP-92490_PP-92490.csv  [Arrhythmogenic_right_ventricular_dysplasia_13...
# PP-92834_PP-92834.csv  [Inborn_genetic_diseases&not_specified&not_pro...
#
#                             FID       IID  PAT  MAT  Sex  Status   Age
# Patient
# BF-1001_BF-1001.csv     BF-1001   BF-1001  0.0  0.0  1.0     1.0  55.0
# BF-1002_BF-1002.csv     BF-1002   BF-1002  0.0  0.0  2.0     2.0  66.0
# BF-1003_BF-1003.csv     BF-1003   BF-1003  0.0  0.0  1.0     2.0  61.0
# BF-1004_BF-1004.csv     BF-1004   BF-1004  0.0  0.0  1.0     2.0  62.0
# BF-1005_BF-1005.csv     BF-1005   BF-1005  0.0  0.0  2.0     1.0  61.0
# ...                         ...       ...  ...  ...  ...     ...   ...
# PP-75564_PP-75564.csv  PP-75564  PP-75564  0.0  0.0  2.0     2.0  77.0
# PP-85242_PP-85242.csv  PP-85242  PP-85242  0.0  0.0  1.0     2.0  63.0
# PP-90456_PP-90456.csv  PP-90456  PP-90456  0.0  0.0  1.0     2.0  82.0
# PP-92490_PP-92490.csv  PP-92490  PP-92490  0.0  0.0  1.0     2.0  72.0
# PP-92834_PP-92834.csv  PP-92834  PP-92834  0.0  0.0  1.0     1.0  66.0
#
# [5826 rows x 12 columns]

# %%
common[common['Status'] == 1]
# Out:
#                                                                   SYMBOL  \
# Patient
# BF-1001_BF-1001.csv    [CEP164, PKD1, PLOD1, DEPDC5, FN1, PDE11A, OBS...
# BF-1005_BF-1005.csv    [DGKZ, NUP93, HYDIN, MYO18B, NLRC4, PLS1, FBN2...
# BF-1009_BF-1009.csv    [BAG3, CEP164, MYO15A, FH, IL17RA, SUCLG1, AHI...
# BF-1012_BF-1012.csv    [ETFA, PKD1, CHRNB1, CACNA1A, POLD1, AGRN, HSP...
# BF-1013_BF-1013.csv    [ADAMTS17, TRPM4, PKLR, DDOST, PEX26, SCN5A, T...
# ...                                                                  ...
# PP-75508_PP-75508.csv  [HMBS, TRPM1, MC1R, UTP4, KIF1C, RYR2, GBA, CH...
# PP-75512_PP-75512.csv  [COL13A1, PDE6C, TUFM, NOD2, SLC4A1, MYOM1, GB...
# PP-75520_PP-75520.csv  [ACADS, PAH, CDH3, ZMPSTE24, NECTIN4, GBA, TBX...
# PP-75547_PP-75547.csv  [TYR, OAS1, CENPJ, FREM2, GALC, ZFYVE26, ABCA3...
# PP-92834_PP-92834.csv  [OTOGL, NOD2, IFIH1, PALLD, PEX6, ALDH5A1, FAN...
#
#                                                                       ID  \
# Patient
# BF-1001_BF-1001.csv    [rs143659874, rs144979397, rs149425237, rs1855...
# BF-1005_BF-1005.csv    [rs76583617, rs145146218, rs79607350, rs149103...
# BF-1009_BF-1009.csv    [rs145393807, rs143659874, rs200146361, rs2015...
# BF-1012_BF-1012.csv    [rs141200145, rs201289693, rs201915086, rs1998...
# BF-1013_BF-1013.csv    [rs201920741, rs148763371, rs150077703, rs1459...
# ...                                                                  ...
# PP-75508_PP-75508.csv  [rs150763621, rs182549235, rs1110400, rs119465...
# PP-75512_PP-75512.csv  [rs200138483, rs148661165, rs34283928, rs10489...
# PP-75520_PP-75520.csv  [rs61732144, rs199475679, rs148535251, rs14138...
# PP-75547_PP-75547.csv  [rs104894313, rs146339735, rs138675304, rs1466...
# PP-92834_PP-92834.csv  [rs76420383, rs61747625, rs139714761, rs140454...
#
#                                                                    HGVSc  \
# Patient
# BF-1001_BF-1001.csv    [NM_014956.5:c.380C>A, NM_001009944.3:c.8293C>...
# BF-1005_BF-1005.csv    [NM_001199267.2:c.2660C>G, NM_014669.5:c.1162C...
# BF-1009_BF-1009.csv    [NM_004281.4:c.280A>T, NM_014956.5:c.380C>A, N...
# BF-1012_BF-1012.csv    [NM_000126.4:c.826A>C, NM_001009944.3:c.8464G>...
# BF-1013_BF-1013.csv    [NM_139057.4:c.1981T>C, NM_017636.4:c.1082T>G,...
# ...                                                                  ...
# PP-75508_PP-75508.csv  [NM_000190.4:c.257A>T, NM_001252024.2:c.3549G>...
# PP-75512_PP-75512.csv  [NM_001368882.1:c.289G>T, NM_006204.4:c.2501A>...
# PP-75520_PP-75520.csv  [NM_000017.4:c.319C>T, NM_000277.3:c.506G>A, N...
# PP-75547_PP-75547.csv  [NM_000372.5:c.1217C>T, NM_016816.4:c.920A>T, ...
# PP-92834_PP-92834.csv  [NM_001378609.3:c.1990C>T, NM_001370466.1:c.21...
#
#                                                           gnomADg_AF_NFE  \
# Patient
# BF-1001_BF-1001.csv    [0.00516024, 0.00743071, 0.00086632, 0.0003998...
# BF-1005_BF-1005.csv    [0.00633925, 0.00239872, 0.00319787, 0.0068620...
# BF-1009_BF-1009.csv    [0.00113469, 0.00516024, 0.00233302, 6.66756e-...
# BF-1012_BF-1012.csv    [0.00126599, 0.0, 6.67022e-05, 0.000133422, 0....
# BF-1013_BF-1013.csv    [0.0, 6.68717e-05, 0.000200267, 0.00193462, 0....
# ...                                                                  ...
# PP-75508_PP-75508.csv  [0.000200053, 0.00579691, 0.0096757, 6.66489e-...
# PP-75512_PP-75512.csv  [0.00020008, 0.00180048, 6.672e-05, 6.664e-05,...
# PP-75520_PP-75520.csv  [0.0, 0.000133209, 0.000867129, 0.000133227, 0...
# PP-75547_PP-75547.csv  [0.00547104, 0.0006, 0.000266489, 6.66489e-05,...
# PP-92834_PP-92834.csv  [0.00193411, 0.00539856, 0.000200428, 0.004334...
#
#                                                            ClinVar_CLNDN  \
# Patient
# BF-1001_BF-1001.csv    [not_provided&Nephronophthisis_15, Inborn_gene...
# BF-1005_BF-1005.csv    [atypical_cerebral_palsy&not_provided, Nephrot...
# BF-1009_BF-1009.csv    [Myofibrillar_myopathy_6&Dilated_cardiomyopath...
# BF-1012_BF-1012.csv    [not_provided&Multiple_acyl-CoA_dehydrogenase_...
# BF-1013_BF-1013.csv    [Weill-Marchesani_4_syndrome&_recessive&not_pr...
# ...                                                                  ...
# PP-75508_PP-75508.csv  [not_provided&Acute_intermittent_porphyria, no...
# PP-75512_PP-75512.csv  [not_provided&Inborn_genetic_diseases, Achroma...
# PP-75520_PP-75520.csv  [Deficiency_of_butyryl-CoA_dehydrogenase&not_p...
# PP-75547_PP-75547.csv  [Inborn_genetic_diseases&Oculocutaneous_albini...
# PP-92834_PP-92834.csv  [Inborn_genetic_diseases&not_specified&not_pro...
#
#                             FID       IID  PAT  MAT  Sex  Status   Age
# Patient
# BF-1001_BF-1001.csv     BF-1001   BF-1001  0.0  0.0  1.0     1.0  55.0
# BF-1005_BF-1005.csv     BF-1005   BF-1005  0.0  0.0  2.0     1.0  61.0
# BF-1009_BF-1009.csv     BF-1009   BF-1009  0.0  0.0  1.0     1.0  73.0
# BF-1012_BF-1012.csv     BF-1012   BF-1012  0.0  0.0  2.0     1.0  65.0
# BF-1013_BF-1013.csv     BF-1013   BF-1013  0.0  0.0  1.0     1.0  81.0
# ...                         ...       ...  ...  ...  ...     ...   ...
# PP-75508_PP-75508.csv  PP-75508  PP-75508  0.0  0.0  2.0     1.0  58.0
# PP-75512_PP-75512.csv  PP-75512  PP-75512  0.0  0.0  2.0     1.0  51.0
# PP-75520_PP-75520.csv  PP-75520  PP-75520  0.0  0.0  1.0     1.0  63.0
# PP-75547_PP-75547.csv  PP-75547  PP-75547  0.0  0.0  1.0     1.0  52.0
# PP-92834_PP-92834.csv  PP-92834  PP-92834  0.0  0.0  1.0     1.0  66.0
#
# [3486 rows x 12 columns]

# %%
common[common['Status'] == 2]
# Out:
#                                                                   SYMBOL  \
# Patient
# BF-1002_BF-1002.csv    [MYO3A, MYBPC3, SERPINA1, TBCE, TTC21B, VCAN, ...
# BF-1003_BF-1003.csv    [TTLL5, PKD1, STAT5B, CPS1, SLC3A1, SPINK5, CP...
# BF-1004_BF-1004.csv    [GJB6, MIPEP, ATP7B, HEXA, FBN3, SBF1, NBAS, S...
# BF-1006_BF-1006.csv    [CDH23, ITGA7, MC1R, DCTN1, LRBA, TFR2, FGFR1,...
# BF-1008_BF-1008.csv    [SUFU, PRPH, BRIP1, GBA, SEMA3D, SUFU, PRPH, B...
# ...                                                                  ...
# PP-75562_PP-75562.csv  [MMP20, A2ML1, CACNA1C, LRRK2, NUBPL, MYO15A, ...
# PP-75564_PP-75564.csv  [ACADSB, EFEMP2, HIKESHI, LRRK2, LIPC, PKD1, C...
# PP-85242_PP-85242.csv  [MYO3A, ZEB1, BLM, CEP152, TSC2, CREBBP, PIEZO...
# PP-90456_PP-90456.csv  [HPS1, MYBPC3, SUOX, KCNH5, NOD2, ACE, KIF1C, ...
# PP-92490_PP-92490.csv  [CTNNA3, MYO7A, VWA8, ETFA, DUOX2, MAPT, SPTA1...
#
#                                                                       ID  \
# Patient
# BF-1002_BF-1002.csv    [rs72787346, rs375776406, rs28929470, rs140662...
# BF-1003_BF-1003.csv    [rs142169707, rs148812376, rs148793995, rs1148...
# BF-1004_BF-1004.csv    [rs200172266, rs150167906, rs201738967, rs1219...
# BF-1006_BF-1006.csv    [rs41281336, rs149081471, rs1805006, rs1488101...
# BF-1008_BF-1008.csv    [rs377274250, rs58599399, rs4988345, rs7676371...
# ...                                                                  ...
# PP-75562_PP-75562.csv  [rs61753770, rs201562272, rs121912775, rs34637...
# PP-75564_PP-75564.csv  [rs148640214, rs141868759, rs202003795, rs3463...
# PP-85242_PP-85242.csv  [rs146511800, rs118020901, rs144706057, rs2013...
# PP-90456_PP-90456.csv  [rs200004304, rs202139499, rs139444405, rs1437...
# PP-92490_PP-92490.csv  [rs187752783, rs111033287, rs138075452, rs1412...
#
#                                                                    HGVSc  \
# Patient
# BF-1002_BF-1002.csv    [NM_017433.5:c.1559C>T, NM_000256.3:c.2980C>T,...
# BF-1003_BF-1003.csv    [NM_015072.5:c.2891G>A, NM_001009944.3:c.9829C...
# BF-1004_BF-1004.csv    [NM_001110219.3:c.212T>C, NM_005932.4:c.590T>C...
# BF-1006_BF-1006.csv    [NM_022124.6:c.7468G>A, NM_002206.3:c.2569G>A,...
# BF-1008_BF-1008.csv    [NM_016169.4:c.1010A>G, NM_006262.4:c.421G>T, ...
# ...                                                                  ...
# PP-75562_PP-75562.csv  [NM_004771.4:c.1313G>C, NM_144670.6:c.2405G>A,...
# PP-75564_PP-75564.csv  [NM_001609.4:c.1187A>C, NM_016938.5:c.977G>A, ...
# PP-85242_PP-85242.csv  [NM_017433.5:c.170A>C, NM_001174096.2:c.2522A>...
# PP-90456_PP-90456.csv  [NM_000195.5:c.179C>T, NM_000256.3:c.624G>C, N...
# PP-92490_PP-92490.csv  [NM_013266.4:c.1132C>T, NM_000260.4:c.5227C>T,...
#
#                                                           gnomADg_AF_NFE  \
# Patient
# BF-1002_BF-1002.csv    [0.00273224, 0.00026688, 0.00346852, 0.0010658...
# BF-1003_BF-1003.csv    [0.00333023, 0.000867129, 6.66667e-05, 0.00773...
# BF-1004_BF-1004.csv    [0.0006, 0.00113303, 0.000400053, 0.00306585, ...
# BF-1006_BF-1006.csv    [0.00060032, 0.00495779, 0.00653944, 6.66578e-...
# BF-1008_BF-1008.csv    [0.000133333, 0.00493399, 0.00446726, 0.001871...
# ...                                                                  ...
# PP-75562_PP-75562.csv  [0.00439941, 6.66311e-05, 0.000133351, 0.00033...
# PP-75564_PP-75564.csv  [0.000133245, 6.68449e-05, 6.66578e-05, 0.0003...
# PP-85242_PP-85242.csv  [0.00093633, 0.00879297, 0.00166578, 0.0050781...
# PP-90456_PP-90456.csv  [0.0, 6.66578e-05, 0.00020024, 6.66045e-05, 0....
# PP-92490_PP-92490.csv  [0.00140262, 0.00400588, 0.00767485, 0.0012659...
#
#                                                            ClinVar_CLNDN  \
# Patient
# BF-1002_BF-1002.csv    [not_provided&not_specified&Autosomal_recessiv...
# BF-1003_BF-1003.csv    [not_specified&not_provided, Autosomal_dominan...
# BF-1004_BF-1004.csv    [not_provided&Autosomal_recessive_nonsyndromic...
# BF-1006_BF-1006.csv    [Autosomal_recessive_nonsyndromic_hearing_loss...
# BF-1008_BF-1008.csv    [Hereditary_cancer-predisposing_syndrome&Gorli...
# ...                                                                  ...
# PP-75562_PP-75562.csv  [not_provided&Amelogenesis_imperfecta_hypomatu...
# PP-75564_PP-75564.csv  [Deficiency_of_2-methylbutyryl-CoA_dehydrogena...
# PP-85242_PP-85242.csv  [Inborn_genetic_diseases&not_specified&not_pro...
# PP-90456_PP-90456.csv  [Hermansky-Pudlak_syndrome_1&not_provided&Herm...
# PP-92490_PP-92490.csv  [Arrhythmogenic_right_ventricular_dysplasia_13...
#
#                             FID       IID  PAT  MAT  Sex  Status   Age
# Patient
# BF-1002_BF-1002.csv     BF-1002   BF-1002  0.0  0.0  2.0     2.0  66.0
# BF-1003_BF-1003.csv     BF-1003   BF-1003  0.0  0.0  1.0     2.0  61.0
# BF-1004_BF-1004.csv     BF-1004   BF-1004  0.0  0.0  1.0     2.0  62.0
# BF-1006_BF-1006.csv     BF-1006   BF-1006  0.0  0.0  1.0     2.0  59.0
# BF-1008_BF-1008.csv     BF-1008   BF-1008  0.0  0.0  2.0     2.0  69.0
# ...                         ...       ...  ...  ...  ...     ...   ...
# PP-75562_PP-75562.csv  PP-75562  PP-75562  0.0  0.0  2.0     2.0  61.0
# PP-75564_PP-75564.csv  PP-75564  PP-75564  0.0  0.0  2.0     2.0  77.0
# PP-85242_PP-85242.csv  PP-85242  PP-85242  0.0  0.0  1.0     2.0  63.0
# PP-90456_PP-90456.csv  PP-90456  PP-90456  0.0  0.0  1.0     2.0  82.0
# PP-92490_PP-92490.csv  PP-92490  PP-92490  0.0  0.0  1.0     2.0  72.0
#
# [2340 rows x 12 columns]

# %%
genes = []
for i in common.SYMBOL.to_list():
    for j in i:
        genes.append(j)

genes = np.array(genes)
genes = np.setdiff1d(genes, ['nan'])
genes = list(set(genes))
genes = sorted(genes)

# %%
def find_indices(list_to_check, item_to_find):
    return [idx for idx, value in enumerate(list_to_check) if value == item_to_find]
def add_column(common, gene):
    common[gene] = np.nan
    for i in common.index:
        try:
            s = []
            for t in find_indices(common.loc[i, 'SYMBOL'], gene):
                s.append(common.loc[i, 'HGVSc'][t])
            if s!=[]:
                common.loc[i, gene] = str(s)
        except:
            continue
    return common
proba = common
for gene in genes:
    proba = add_column(proba, gene)
result = proba.drop(['SYMBOL', 'ID', 'HGVSc', 'gnomADg_AF_NFE'], axis = 1)
result.dropna(axis='columns',how='all', inplace=True)
def snips_list(gene):
    prelist = result[f'{gene}'].unique()
    l = re.findall(r"N\S+[AGTC]", str(prelist)) # S - непробельный символ
    l = set(l)
    l = list(l)
    return l

# %%
len(genes)
# Out:
# 1799

# %%
import pandas as pd
import re
# Preprocess DataFrame to extract necessary data
cases = result[result['Status'] == 2]
control = result[result['Status'] == 1]


# Iterate over pairs of genes
for i in range(len(genes)):
    l = snips_list(genes[i])
    for j in range(i + 1, len(genes)):
        l2 = snips_list(genes[j])
        
        # Iterate over snips in gene pairs
        for snip in l:
            for snipp in l2:
                # Perform queries only once
                cases_number = cases[cases[genes[i]].str.contains(snip) & cases[genes[j]].str.contains(snipp)].shape[0]
                control_number = control[control[genes[i]].str.contains(snip) & control[genes[j]].str.contains(snipp)].shape[0]
                maf_cases = cases_number / (cases.shape[0] * 2)
                maf_control = control_number / (control.shape[0] * 2)
                cases_mut1 = cases[cases[genes[i]].str.contains(snip) == True].shape[0]
                control_mut1 = control[control[genes[i]].str.contains(snip) == True].shape[0]
                MAF_cases_mut1 = cases_mut1 / (cases.shape[0] * 2)
                MAF_control_mut1 = control_mut1 / (control.shape[0] * 2)
                cases_mut2 = cases[cases[genes[j]].str.contains(snipp) == True].shape[0]
                control_mut2 = control[control[genes[j]].str.contains(snipp) == True].shape[0]
                MAF_cases_mut2 = cases_mut2 / (cases.shape[0] * 2)
                MAF_control_mut2 = control_mut2 / (control.shape[0] * 2)
                
                    # Check if any cases exist
                if cases_number != 0 or control_number != 0:
                    ans0 = pd.DataFrame([{
                            'Mutation1': f'{genes[i]} {snip}',
                            'Mutation2': f'{genes[j]} {snipp}',
                            'N cases': cases_number,
                            'N control': control_number,
                            'MAF in cases': maf_cases,
                            'MAF in control': maf_control,
                            'Mutation1 only': f'{genes[i]} {snip}',
                            'N cases Mutation1': cases_mut1,
                            'N control Mutation1': control_mut1,
                            'MAF in cases Mutation1': MAF_cases_mut1,
                            'MAF in control Mutation1': MAF_control_mut1,
                            'Mutation2 only': f'{genes[j]} {snipp}',
                            'N cases Mutation2': cases_mut2,
                            'N control Mutation2': control_mut2,
                            'MAF in cases Mutation2':  MAF_cases_mut2,
                            'MAF in control Mutation2': MAF_control_mut2
                        }])

                        # Write to CSV
                    ans0.to_csv(f'All_unc/{genes[i]}.csv', mode='a', header=False, index=False)
                    ans0 = None
                else:
                    continue

# %% [markdown]
# # FROM the check - list

# %%
etalon = ['ASH1L','ASXL3', 'ATP13A2','BAG3', 'BIN3', 'BRIP1', 'BST1', 'CAB39L','CAMK2D', 'CASC16', 'CD19', 'CHCHD2', 'CHRNB1', 'CLCN3',
 'CRLS1',
 'CTSB',
 'CYRIB',
 'DJ-1',
 'DLG2',
 'DNAH17',
 'DNAJC13',
 'DNAJC6',
 'DYRK1A',
 'EHMT2-AS1',
 'EIF4G1',
 'ELOVL7',
 'ENSG00000234500',
 'ENSG00000251095',
 'ENSG00000253496',
 'ENSG00000257239',
 'ENSG00000259675',
 'ENSG00000270892',
 'ENSG00000273734',
 'ENSG00000283563',
 'ENSG00000286074',
 'ENSG00000286235',
 'ENSG00000287401',
 'ENSG00000288563',
 'ENSG00000291136',
 'FAM171A2',
 'FAM47E',
 'FAM47E-STBD1',
 'FBXO7',
 'FLG-AS1',
 'GAK',
 'GBA',
 'GBA1',
 'GBF1',
 'GCH1',
 'GIGYF2',
 'GPNMB',
 'GXYLT1',
 'HIP1R',
 'HRNR',
 'HTRA2',
 'IGSF9B',
 'INPP5F',
 'IP6K2',
 'ITGA8',
 'ITPKB',
 'KANSL1',
 'KCNIP3',
 'KCNS3',
 'KPNA1',
 'LCORL',
 'LINC02210-CRHR1',
 'LRRK2',
 'LRRK2-DT',
 'MAP4K4',
 'MAPT-AS1',
 'MCCC1',
 'MED12L',
 'MIPOL1',
 'MUC19',
 'NOD2',
 'NSF',
 'PHB1P21',
 'PINK1',
 'PLA2G6',
 'PMVK',
 'PRKN',
 'PSAP',
 'RAB29',
 'RABEP2',
 'RBMS3',
 'RETREG3',
 'RIT2',
 'RNF141',
 'RPS6KL1',
 'SCARB2',
 'SETD1A',
 'SH3GL2',
 'SIPA1L2',
 'SLC44A4',
 'SNCA',
 'SPPL2B',
 'SPTSSB',
 'SYNJ1',
 'SYT17',
 'TBC1D5',
 'TMEM163',
 'TMEM175',
 'TRIM40',
 'UBAP2',
 'UBTF',
 'UCH-L1',
 'VPS13C',
 'VPS35', 'WNT3']

# %%
df_after_check = df_CADD.query(f"SYMBOL in {etalon}")

# %%
df_after_check
# Out:
#                                        Patient  CHROM        POS           ID  \
# 31             PD-PDKK097AHR_PD-PDKK097AHR.csv      1  155236246   rs75548401
# 62                       LB-07856_LB-07856.csv      1  155235843   rs76763715
# 105                      PP-41467_PP-41467.csv      1  155235843   rs76763715
# 357    HB-PD_INVMJ225EDX_HB-PD_INVMJ225EDX.csv      1   20645615   rs55831733
# 467    HB-PD_INVUL535YVX_HB-PD_INVUL535YVX.csv      1   16990276  rs200924194
# ...                                        ...    ...        ...          ...
# 20201                    PP-70714_PP-70714.csv     10  119676794  rs117749531
# 20685                    PP-74977_PP-74977.csv     10  119676794  rs117749531
# 21044                    LB-07204_LB-07204.csv     10  119676794  rs117749531
# 21726                      BF-1092_BF-1092.csv     10  119669950  rs145393807
# 22445                LC-1390011_LC-1390011.csv     10   71851249  rs375720661
#
#         SYMBOL   Gene                  HGVSc                    HGVSp  \
# 31         GBA   2629  NM_000157.4:c.1223C>T  NP_000148.2:p.Thr408Met
# 62         GBA   2629  NM_000157.4:c.1226A>G  NP_000148.2:p.Asn409Ser
# 105        GBA   2629  NM_000157.4:c.1226A>G  NP_000148.2:p.Asn409Ser
# 357      PINK1  65018  NM_032409.3:c.1015G>A  NP_115785.1:p.Ala339Thr
# 467    ATP13A2  23400  NM_022089.4:c.2263C>G  NP_071372.1:p.Gln755Glu
# ...        ...    ...                    ...                      ...
# 20201     BAG3   9531  NM_004281.4:c.1240G>A  NP_004272.2:p.Glu414Lys
# 20685     BAG3   9531  NM_004281.4:c.1240G>A  NP_004272.2:p.Glu414Lys
# 21044     BAG3   9531  NM_004281.4:c.1240G>A  NP_004272.2:p.Glu414Lys
# 21726     BAG3   9531   NM_004281.4:c.280A>T   NP_004272.2:p.Ile94Phe
# 22445     PSAP   5660   NM_002778.4:c.-28A>C                      NaN
#
#        CADD_PHRED                                ClinVar_CLNSIG  \
# 31           21.3  Conflicting_interpretations_of_pathogenicity
# 62           24.1      Pathogenic/Likely_pathogenic&risk_factor
# 105          24.1      Pathogenic/Likely_pathogenic&risk_factor
# 357          24.3  Conflicting_interpretations_of_pathogenicity
# 467          23.1  Conflicting_interpretations_of_pathogenicity
# ...           ...                                           ...
# 20201        22.5  Conflicting_interpretations_of_pathogenicity
# 20685        22.5  Conflicting_interpretations_of_pathogenicity
# 21044        22.5  Conflicting_interpretations_of_pathogenicity
# 21726        25.7  Conflicting_interpretations_of_pathogenicity
# 22445        21.6  Conflicting_interpretations_of_pathogenicity
#
#                                            ClinVar_CLNDN  LoFtool  \
# 31     Inborn_genetic_diseases&not_specified&not_prov...  0.00827
# 62     Parkinson_disease&Parkinson_disease&_late-onse...  0.00827
# 105    Parkinson_disease&Parkinson_disease&_late-onse...  0.00827
# 357    not_provided&Autosomal_recessive_early-onset_P...  0.78800
# 467    Autosomal_recessive_spastic_paraplegia_type_78...  0.02890
# ...                                                  ...      ...
# 20201  not_specified&Myofibrillar_myopathy_6&Dilated_...  0.12700
# 20685  not_specified&Myofibrillar_myopathy_6&Dilated_...  0.12700
# 21044  not_specified&Myofibrillar_myopathy_6&Dilated_...  0.12700
# 21726  Myofibrillar_myopathy_6&Dilated_cardiomyopathy...  0.12700
# 22445  not_specified&Krabbe_disease_due_to_saposin_A_...  0.09070
#
#                     CAROL
# 31         Neutral(0.860)
# 62     Deleterious(0.989)
# 105    Deleterious(0.989)
# 357    Deleterious(0.999)
# 467    Deleterious(0.999)
# ...                   ...
# 20201      Neutral(0.970)
# 20685      Neutral(0.970)
# 21044      Neutral(0.970)
# 21726  Deleterious(0.999)
# 22445                 NaN
#
# [2670 rows x 13 columns]

# %%
aggfuncs = ['unique']
df_group = df_after_check.groupby('Patient')[['SYMBOL', 'ID', 'HGVSc', 'HGVSp', 'ClinVar_CLNDN']].agg(lambda x: list(x))
df_group
# Out:
#                                         SYMBOL                        ID  \
# Patient
# BF-1002_BF-1002.csv                     [GCH1]             [rs104894434]
# BF-1008_BF-1008.csv               [GBA, BRIP1]   [rs76763715, rs4988345]
# BF-1009_BF-1009.csv                     [BAG3]             [rs145393807]
# BF-1012_BF-1012.csv                   [CHRNB1]             [rs201915086]
# BF-1021_BF-1021.csv                [GBA, NOD2]   [rs78973108, rs2066844]
# ...                                        ...                       ...
# SY-PDTW883TFJ_SY-PDTW883TFJ.csv         [PMVK]             [rs373000976]
# SY-PDVD904ZLL_SY-PDVD904ZLL.csv  [MCCC1, NOD2]  [rs148616219, rs2066844]
# SY-PDWJ270UA9_SY-PDWJ270UA9.csv         [NOD2]              [rs61747625]
# SY-PDWY946KH3_SY-PDWY946KH3.csv         [NOD2]               [rs2066845]
# SY-PDXP355GHP_SY-PDXP355GHP.csv          [GBA]              [rs76763715]
#
#                                                                             HGVSc  \
# Patient
# BF-1002_BF-1002.csv                                        [NM_000161.3:c.662T>C]
# BF-1008_BF-1008.csv                 [NM_000157.4:c.1226A>G, NM_032043.3:c.517C>T]
# BF-1009_BF-1009.csv                                        [NM_004281.4:c.280A>T]
# BF-1012_BF-1012.csv                                        [NM_000747.3:c.305G>C]
# BF-1021_BF-1021.csv              [NM_000157.4:c.887G>A, NM_001370466.1:c.2023C>T]
# ...                                                                           ...
# SY-PDTW883TFJ_SY-PDTW883TFJ.csv                             [NM_006556.4:c.79G>T]
# SY-PDVD904ZLL_SY-PDVD904ZLL.csv  [NM_020166.5:c.254A>C, NM_001370466.1:c.2023C>T]
# SY-PDWJ270UA9_SY-PDWJ270UA9.csv                        [NM_001370466.1:c.2183C>T]
# SY-PDWY946KH3_SY-PDWY946KH3.csv                        [NM_001370466.1:c.2641G>C]
# SY-PDXP355GHP_SY-PDXP355GHP.csv                           [NM_000157.4:c.1226A>G]
#
#                                                                              HGVSp  \
# Patient
# BF-1002_BF-1002.csv                                      [NP_000152.1:p.Met221Thr]
# BF-1008_BF-1008.csv              [NP_000148.2:p.Asn409Ser, NP_114432.2:p.Arg173...
# BF-1009_BF-1009.csv                                       [NP_004272.2:p.Ile94Phe]
# BF-1012_BF-1012.csv                                      [NP_000738.2:p.Arg102Pro]
# BF-1021_BF-1021.csv              [NP_000148.2:p.Arg296Gln, NP_001357395.1:p.Arg...
# ...                                                                            ...
# SY-PDTW883TFJ_SY-PDTW883TFJ.csv                           [NP_006547.1:p.Glu27Ter]
# SY-PDVD904ZLL_SY-PDVD904ZLL.csv  [NP_064551.3:p.Asn85Thr, NP_001357395.1:p.Arg6...
# SY-PDWJ270UA9_SY-PDWJ270UA9.csv                       [NP_001357395.1:p.Ala728Val]
# SY-PDWY946KH3_SY-PDWY946KH3.csv                       [NP_001357395.1:p.Gly881Arg]
# SY-PDXP355GHP_SY-PDXP355GHP.csv                          [NP_000148.2:p.Asn409Ser]
#
#                                                                      ClinVar_CLNDN
# Patient
# BF-1002_BF-1002.csv              [Dystonia_5&GTP_cyclohydrolase_I_deficiency&no...
# BF-1008_BF-1008.csv              [Parkinson_disease&Parkinson_disease&_late-ons...
# BF-1009_BF-1009.csv              [Myofibrillar_myopathy_6&Dilated_cardiomyopath...
# BF-1012_BF-1012.csv              [Congenital_myasthenic_syndrome_2A&Congenital_...
# BF-1021_BF-1021.csv              [Gaucher_disease_type_III&Gaucher_disease_type...
# ...                                                                            ...
# SY-PDTW883TFJ_SY-PDTW883TFJ.csv  [Porokeratosis_1&_Mibelli_type&not_provided&Li...
# SY-PDVD904ZLL_SY-PDVD904ZLL.csv  [not_provided&3-methylcrotonyl-CoA_carboxylase...
# SY-PDWJ270UA9_SY-PDWJ270UA9.csv  [Inflammatory_bowel_disease_1&Blau_syndrome&Re...
# SY-PDWY946KH3_SY-PDWY946KH3.csv  [Autoinflammatory_syndrome&Yao_syndrome&Psoria...
# SY-PDXP355GHP_SY-PDXP355GHP.csv  [Parkinson_disease&Parkinson_disease&_late-ons...
#
# [2257 rows x 5 columns]

# %%
df_group.query("@df_group.SYMBOL.str.len() >= 2").to_csv('Results/After_check_ClinVar_result.csv')

# %%
df_two = df_group.query("@df_group.SYMBOL.str.len() >= 2")

# %%
df_two
# Out:
#                                                         SYMBOL  \
# Patient
# BF-1008_BF-1008.csv                               [GBA, BRIP1]
# BF-1021_BF-1021.csv                                [GBA, NOD2]
# HB-PD_INVAH314MA5_HB-PD_INVAH314MA5.csv        [DNAJC13, NOD2]
# HB-PD_INVAK106DV5_HB-PD_INVAK106DV5.csv           [NOD2, BAG3]
# HB-PD_INVAR519XPV_HB-PD_INVAR519XPV.csv          [NOD2, LRRK2]
# ...                                                        ...
# PP-75505_PP-75505.csv                          [DNAH17, LRRK2]
# PP-75512_PP-75512.csv                              [GBA, NOD2]
# SY-NIH_INVEP886EEYYL_SY-NIH_INVEP886EEYYL.csv    [NOD2, LRRK2]
# SY-PDGT137BDP_SY-PDGT137BDP.csv                    [GBA, NOD2]
# SY-PDVD904ZLL_SY-PDVD904ZLL.csv                  [MCCC1, NOD2]
#
#                                                                       ID  \
# Patient
# BF-1008_BF-1008.csv                              [rs76763715, rs4988345]
# BF-1021_BF-1021.csv                              [rs78973108, rs2066844]
# HB-PD_INVAH314MA5_HB-PD_INVAH314MA5.csv          [rs61748101, rs2066844]
# HB-PD_INVAK106DV5_HB-PD_INVAK106DV5.csv         [rs2066845, rs145393807]
# HB-PD_INVAR519XPV_HB-PD_INVAR519XPV.csv        [rs104895467, rs34637584]
# ...                                                                  ...
# PP-75505_PP-75505.csv                           [rs76449350, rs34637584]
# PP-75512_PP-75512.csv                          [rs76763715, rs104895438]
# SY-NIH_INVEP886EEYYL_SY-NIH_INVEP886EEYYL.csv    [rs2066845, rs78501232]
# SY-PDGT137BDP_SY-PDGT137BDP.csv                  [rs76763715, rs2066844]
# SY-PDVD904ZLL_SY-PDVD904ZLL.csv                 [rs148616219, rs2066844]
#
#                                                                                            HGVSc  \
# Patient
# BF-1008_BF-1008.csv                                [NM_000157.4:c.1226A>G, NM_032043.3:c.517C>T]
# BF-1021_BF-1021.csv                             [NM_000157.4:c.887G>A, NM_001370466.1:c.2023C>T]
# HB-PD_INVAH314MA5_HB-PD_INVAH314MA5.csv        [NM_015268.4:c.3872A>G, NM_001370466.1:c.2023C>T]
# HB-PD_INVAK106DV5_HB-PD_INVAK106DV5.csv         [NM_001370466.1:c.2641G>C, NM_004281.4:c.280A>T]
# HB-PD_INVAR519XPV_HB-PD_INVAR519XPV.csv        [NM_001370466.1:c.2474A>G, NM_198578.4:c.6055G>A]
# ...                                                                                          ...
# PP-75505_PP-75505.csv                             [NM_173628.4:c.4798G>A, NM_198578.4:c.6055G>A]
# PP-75512_PP-75512.csv                          [NM_000157.4:c.1226A>G, NM_001370466.1:c.1753G>A]
# SY-NIH_INVEP886EEYYL_SY-NIH_INVEP886EEYYL.csv  [NM_001370466.1:c.2641G>C, NM_198578.4:c.1000G>A]
# SY-PDGT137BDP_SY-PDGT137BDP.csv                [NM_000157.4:c.1226A>G, NM_001370466.1:c.2023C>T]
# SY-PDVD904ZLL_SY-PDVD904ZLL.csv                 [NM_020166.5:c.254A>C, NM_001370466.1:c.2023C>T]
#
#                                                                                            HGVSp  \
# Patient
# BF-1008_BF-1008.csv                            [NP_000148.2:p.Asn409Ser, NP_114432.2:p.Arg173...
# BF-1021_BF-1021.csv                            [NP_000148.2:p.Arg296Gln, NP_001357395.1:p.Arg...
# HB-PD_INVAH314MA5_HB-PD_INVAH314MA5.csv        [NP_056083.3:p.Glu1291Gly, NP_001357395.1:p.Ar...
# HB-PD_INVAK106DV5_HB-PD_INVAK106DV5.csv        [NP_001357395.1:p.Gly881Arg, NP_004272.2:p.Ile...
# HB-PD_INVAR519XPV_HB-PD_INVAR519XPV.csv        [NP_001357395.1:p.Asn825Ser, NP_940980.4:p.Gly...
# ...                                                                                          ...
# PP-75505_PP-75505.csv                          [NP_775899.3:p.Val1600Met, NP_940980.4:p.Gly20...
# PP-75512_PP-75512.csv                          [NP_000148.2:p.Asn409Ser, NP_001357395.1:p.Ala...
# SY-NIH_INVEP886EEYYL_SY-NIH_INVEP886EEYYL.csv  [NP_001357395.1:p.Gly881Arg, NP_940980.4:p.Glu...
# SY-PDGT137BDP_SY-PDGT137BDP.csv                [NP_000148.2:p.Asn409Ser, NP_001357395.1:p.Arg...
# SY-PDVD904ZLL_SY-PDVD904ZLL.csv                [NP_064551.3:p.Asn85Thr, NP_001357395.1:p.Arg6...
#
#                                                                                    ClinVar_CLNDN
# Patient
# BF-1008_BF-1008.csv                            [Parkinson_disease&Parkinson_disease&_late-ons...
# BF-1021_BF-1021.csv                            [Gaucher_disease_type_III&Gaucher_disease_type...
# HB-PD_INVAH314MA5_HB-PD_INVAH314MA5.csv        [Parkinson_disease_21&not_provided, Autoinflam...
# HB-PD_INVAK106DV5_HB-PD_INVAK106DV5.csv        [Autoinflammatory_syndrome&Yao_syndrome&Psoria...
# HB-PD_INVAR519XPV_HB-PD_INVAR519XPV.csv        [Blau_syndrome&Regional_enteritis&Autoinflamma...
# ...                                                                                          ...
# PP-75505_PP-75505.csv                          [Inborn_genetic_diseases&not_provided, not_pro...
# PP-75512_PP-75512.csv                          [Parkinson_disease&Parkinson_disease&_late-ons...
# SY-NIH_INVEP886EEYYL_SY-NIH_INVEP886EEYYL.csv  [Autoinflammatory_syndrome&Yao_syndrome&Psoria...
# SY-PDGT137BDP_SY-PDGT137BDP.csv                [Parkinson_disease&Parkinson_disease&_late-ons...
# SY-PDVD904ZLL_SY-PDVD904ZLL.csv                [not_provided&3-methylcrotonyl-CoA_carboxylase...
#
# [374 rows x 5 columns]
